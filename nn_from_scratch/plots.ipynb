# %%
import matplotlib.pyplot as plt 
from math import exp

# %%
def sigmoid_like(x):
    if x <0.4: 
        return 0
    if x >0.6: 
        return 1
    return 5*x-2

# %%
def sigmoid(x: float): 
    # write the function of sigmoid
    sigmoid_output = exp(x)/(1 + exp(x))
    return sigmoid_output

# %%
[sigmoid(0), sigmoid(0.3), sigmoid(0.3), sigmoid(0.6)]
# Out:
# [0.5, 0.574442516811659, 0.574442516811659, 0.6456563062257954]

# %%
plt.plot([val for val in range(-10,11)], [sigmoid_like(x) for x in range(-10, 11)])

# %%
import pickle

loss_values = pickle.load(open("/Users/anu_guru/Documents/Guru/why_series/nn_from_scratch/sq_fn_loss.pkl", "rb"))

# %%
plt.plot(loss_values)
